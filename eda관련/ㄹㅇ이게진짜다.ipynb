# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_201903.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_201903.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_201903.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10964510 entries, 0 to 10964509
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 920.2+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_201904.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_201904.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_201904.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10896268 entries, 0 to 10896267
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 914.5+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_201905.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_201905.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_201905.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11309438 entries, 0 to 11309437
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 949.1+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_201906.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_201906.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_201906.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11076269 entries, 0 to 11076268
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 929.6+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_201908.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_201908.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_201908.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11175975 entries, 0 to 11175974
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 937.9+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_201909.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_201909.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_201909.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10817261 entries, 0 to 10817260
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 907.8+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_201910.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_201910.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_201910.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11057218 entries, 0 to 11057217
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 928.0+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_201911.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_201911.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_201911.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10818838 entries, 0 to 10818837
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 908.0+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_201912.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_201912.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_201912.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10979062 entries, 0 to 10979061
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 921.4+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202001.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202001.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202001.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10620529 entries, 0 to 10620528
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 891.3+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202002.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202002.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202002.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9771192 entries, 0 to 9771191
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 820.0+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202003.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202003.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202003.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9576991 entries, 0 to 9576990
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 803.7+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202004.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202004.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202004.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9838957 entries, 0 to 9838956
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 825.7+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202005.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202005.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202005.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10832952 entries, 0 to 10832951
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 909.1+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202006.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202006.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202006.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10603054 entries, 0 to 10603053
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 889.8+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202007.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202007.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202007.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10737797 entries, 0 to 10737796
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 901.2+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202008.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202008.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202008.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10488019 entries, 0 to 10488018
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 880.2+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202009.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202009.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202009.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10032026 entries, 0 to 10032025
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 841.9+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202010.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202010.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202010.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10576779 entries, 0 to 10576778
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 887.6+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202011.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202011.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202011.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10268675 entries, 0 to 10268674
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 861.8+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202012.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202012.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202012.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9493182 entries, 0 to 9493181
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 796.7+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202101.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202101.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202101.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9394550 entries, 0 to 9394549
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 788.4+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202102.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202102.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202102.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9724480 entries, 0 to 9724479
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 816.1+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202103.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202103.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202103.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10375753 entries, 0 to 10375752
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 870.8+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202104.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202104.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202104.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10444184 entries, 0 to 10444183
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 876.5+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202105.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202105.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202105.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10747815 entries, 0 to 10747814
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 902.0+ MB

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np


path='E:\\'
os.listdir(path)

UPJONG_Df=pd.read_csv(os.path.join(path, '블록_성별연령대별_202106.txt'),encoding='utf-8', sep='`')
UPJONG_Df=UPJONG_Df.drop(UPJONG_Df.columns[[0,2,4,6,8,10,12,14]],axis=1)
UPJONG_Df.rename(columns={'서울시민업종코드':'UPJONG_CD'},inplace=True)

path2='E:\\063. 서울시민의 업종별 카드소비 패턴 데이터\\2. 파일데이터'
os.listdir(path)
blockDf=pd.read_excel(os.path.join(path2, '블록코드정리표 - 최종본.xlsx'))
blockDf2=pd.DataFrame({
        'BLCK_CD':blockDf['BLCK_CD,C,6'],
    'ADSTRD_CD':blockDf['ADSTRD_CD,C,10'],
    'SIGNGU_CD':blockDf['SIGNGU_CD,C,5'],
    'BLCK':blockDf['BLCK_NM,C,30'],
    'UNVTW_AT':blockDf['UNVTW_AT,C,1'],
    'RASTSP_AT':blockDf['RASTSP_AT,C,1']
})
sectorCodeDf=pd.read_csv(os.path.join(path, '서울시민 카드소비 업종코드.csv'), encoding='utf-8')
sectorCodeDf['UPJONG_CD'] = sectorCodeDf['UPJONG_CD'].str.upper()

UPJONG_Df=pd.merge(UPJONG_Df, sectorCodeDf, how='left', on='UPJONG_CD')
UPJONG_Df.info()
UPJONG_Df.rename(columns={'고객주소블록코드':'BLCK_CD'},inplace=True)
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
dataForRank=pd.merge(UPJONG_Df, blockDf2, how='left', on='BLCK_CD')
sac_df=dataForRank.pivot_table(index=['BLCK','ADSTRD_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['BLCK','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['ADSTRD_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('동연령성별응용집계_202106.csv')

##여기서부턴 구 단위
sac_df=dataForRank.pivot_table(index=['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별','CLASS1'],values=['카드이용금액계','카드이용건수계'],aggfunc='sum')
sac_df
dataForRank2=sac_df.reset_index()
dataForRank2['카드이용건수계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용건수계'].rank(method='min',ascending=False)
dataForRank2['카드이용금액계순위']=dataForRank2.groupby(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','성별','연령대별'])['카드이용금액계'].rank(method='min', ascending=False)
dataForRank3=dataForRank2.drop(['SIGNGU_CD','UNVTW_AT','RASTSP_AT','카드이용건수계','카드이용금액계'],axis=1)
dataForRank3.to_csv('구연령성별응용집계_202106.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10675880 entries, 0 to 10675879
# Data columns (total 10 columns):
# UPJONG_CD    object
# 기준년월         int64
# 고객주소블록코드     int64
# 성별           object
# 연령대별         object
# 카드이용금액계      int64
# 카드이용건수계      int64
# CLASS1       object
# CLASS2       object
# CLASS3       object
# dtypes: int64(4), object(6)
# memory usage: 896.0+ MB
