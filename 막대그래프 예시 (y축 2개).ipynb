# %%
fig = plt.figure()

ax = fig.add_subplot(111)
ax2 = ax.twinx()

width = 0.3

visual_1.고객수.plot(kind='bar', color="red", ax=ax, width=width, position=0, figsize=(30,15))
visual_1.이용건수.plot(kind='bar', color="blue", ax=ax, width=width, position=1, figsize=(30,15))
visual_1.이용금액.plot(kind='bar', color="green", ax=ax2, width=width, position=2, figsize=(30,15))

plt.show()
